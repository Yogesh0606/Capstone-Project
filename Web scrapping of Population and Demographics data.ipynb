# %% [markdown]
# <H2>Web scrapping of Population and Demographics data of New York city from Wikipedia.

# %% [markdown]
# <H4>Population Data

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from bs4) (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from beautifulsoup4->bs4) (1.7.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.18.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geopy) (1.49)

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.10.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.4.5.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

# conda install -c anaconda beautiful-soup --yes
from bs4 import BeautifulSoup # package for parsing HTML and XML documents

import csv # implements classes to read and write tabular data in CSV form

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/Demographics_of_New_York_City').text
soup = BeautifulSoup(website_url,'lxml')
table = soup.find('table',{'class':'wikitable sortable'})
#print(soup.prettify())

headers = [header.text for header in table.find_all('th')]

table_rows = table.find_all('tr')        
rows = []
for row in table_rows:
   td = row.find_all('td')
   row = [row.text for row in td]
   rows.append(row)

with open('BON2_POPULATION1.csv', 'w') as f:
   writer = csv.writer(f)
   writer.writerow(headers)
   writer.writerows(row for row in rows if row)

# %%
Pop_data=pd.read_csv('BON2_POPULATION1.csv')
Pop_data.drop(Pop_data.columns[[7,8,9,10,11]], axis=1,inplace=True)
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
Pop_data.columns = Pop_data.columns.str.replace(' ', '')
Pop_data.columns = Pop_data.columns.str.replace('\'','')
Pop_data.rename(columns={'Borough':'persons_sq_mi','County':'persons_sq_km'}, inplace=True)
Pop_data
# Out:
#                        NewYorkCitysfiveboroughsvte\n   Jurisdiction\n  \
# 0                                        The Bronx\n      \n  Bronx\n
# 1                                         Brooklyn\n      \n  Kings\n
# 2                                        Manhattan\n   \n  New York\n
# 3                                           Queens\n    \n   Queens\n
# 4                                    Staten Island\n  \n   Richmond\n
# 5                                   City of New York        8,398,748
# 6                                  State of New York       19,745,289
# 7  Sources:[14] and see individual borough articl...              NaN
#
#   Population\n GrossDomesticProduct\n Landarea\n Density\n persons_sq_mi  \
# 0  1,432,132\n               42.695\n   29,200\n   42.10\n      109.04\n
# 1  2,582,830\n               91.559\n   34,600\n   70.82\n      183.42\n
# 2  1,628,701\n              600.244\n  360,900\n   22.83\n       59.13\n
# 3  2,278,906\n               93.310\n   39,600\n  108.53\n      281.09\n
# 4    476,179\n               14.514\n   30,300\n   58.37\n      151.18\n
# 5      842.343                 97,700     302.64    783.83        28,188
# 6    1,701.399                 85,700     47,214   122,284         416.4
# 7          NaN                    NaN        NaN       NaN           NaN
#
#    squarekm  persons/sq.mi  persons/km2\n
# 0       NaN            NaN            NaN
# 1       NaN            NaN            NaN
# 2       NaN            NaN            NaN
# 3       NaN            NaN            NaN
# 4       NaN            NaN            NaN
# 5       NaN            NaN            NaN
# 6       NaN            NaN            NaN
# 7       NaN            NaN            NaN

# %%
Pop_data.rename(columns = {'NewYorkCitysfiveboroughsvte\n' : 'Borough',
                   'Jurisdiction\n':'County',
                   'Population\n':'Estimate_2017', 
                   'Landarea\n':'square_miles',
                    'Density\n':'square_km'}, inplace=True)
Pop_data
# Out:
#                                             Borough       County  \
# 0                                         The Bronx        Bronx
# 1                                          Brooklyn        Kings
# 2                                         Manhattan     New York
# 3                                            Queens       Queens
# 4                                     Staten Island     Richmond
# 5                                  City of New York    8,398,748
# 6                                 State of New York   19,745,289
# 7  Sources:[14] and see individual borough articles          NaN
#
#   Estimate_2017 GrossDomesticProduct\n square_miles square_km persons_sq_mi  \
# 0     1,432,132               42.695\n       29,200     42.10        109.04
# 1     2,582,830               91.559\n       34,600     70.82        183.42
# 2     1,628,701              600.244\n      360,900     22.83         59.13
# 3     2,278,906               93.310\n       39,600    108.53        281.09
# 4       476,179               14.514\n       30,300     58.37        151.18
# 5       842.343                 97,700       302.64    783.83        28,188
# 6     1,701.399                 85,700       47,214   122,284         416.4
# 7           NaN                    NaN          NaN       NaN           NaN
#
#    squarekm  persons/sq.mi  persons/km2\n
# 0       NaN            NaN            NaN
# 1       NaN            NaN            NaN
# 2       NaN            NaN            NaN
# 3       NaN            NaN            NaN
# 4       NaN            NaN            NaN
# 5       NaN            NaN            NaN
# 6       NaN            NaN            NaN
# 7       NaN            NaN            NaN

# %%
Pop_data['Borough']=Pop_data['Borough'].replace(to_replace='\n', value='', regex=True)
Pop_data['County']=Pop_data['County'].replace(to_replace='\n', value='', regex=True)
Pop_data['Estimate_2017']=Pop_data['Estimate_2017'].replace(to_replace='\n', value='', regex=True)
Pop_data['square_miles']=Pop_data['square_miles'].replace(to_replace='\n', value='', regex=True)
Pop_data['square_km']=Pop_data['square_km'].replace(to_replace='\n', value='', regex=True)
Pop_data['persons_sq_mi']=Pop_data['persons_sq_mi'].replace(to_replace='\n', value='', regex=True)
Pop_data['square_km']=Pop_data['square_km'].replace(to_replace='\n', value='', regex=True)
Pop_data
# Out:
#                                             Borough       County  \
# 0                                         The Bronx        Bronx
# 1                                          Brooklyn        Kings
# 2                                         Manhattan     New York
# 3                                            Queens       Queens
# 4                                     Staten Island     Richmond
# 5                                  City of New York    8,398,748
# 6                                 State of New York   19,745,289
# 7  Sources:[14] and see individual borough articles          NaN
#
#   Estimate_2017 GrossDomesticProduct\n square_miles square_km persons_sq_mi  \
# 0     1,432,132               42.695\n       29,200     42.10        109.04
# 1     2,582,830               91.559\n       34,600     70.82        183.42
# 2     1,628,701              600.244\n      360,900     22.83         59.13
# 3     2,278,906               93.310\n       39,600    108.53        281.09
# 4       476,179               14.514\n       30,300     58.37        151.18
# 5       842.343                 97,700       302.64    783.83        28,188
# 6     1,701.399                 85,700       47,214   122,284         416.4
# 7           NaN                    NaN          NaN       NaN           NaN
#
#    squarekm  persons/sq.mi  persons/km2\n
# 0       NaN            NaN            NaN
# 1       NaN            NaN            NaN
# 2       NaN            NaN            NaN
# 3       NaN            NaN            NaN
# 4       NaN            NaN            NaN
# 5       NaN            NaN            NaN
# 6       NaN            NaN            NaN
# 7       NaN            NaN            NaN

# %%
Pop_data.loc[5:,['persons_sq_mi','square_km']] = Pop_data.loc[2:,['persons_sq_mi','square_km']].shift(1,axis=1)
Pop_data.loc[5:,['square_km','persons_sq_mi']] = Pop_data.loc[2:,['square_km','persons_sq_mi']].shift(1,axis=1)
Pop_data.loc[5:,['square_miles','square_km']] = Pop_data.loc[2:,['square_miles','square_km']].shift(1,axis=1)
Pop_data.loc[5:,['Estimate_2017','square_miles']] = Pop_data.loc[2:,['Estimate_2017','square_miles']].shift(1,axis=1)
Pop_data.loc[5:,['County','Estimate_2017']] = Pop_data.loc[2:,['County','Estimate_2017']].shift(1,axis=1)
Pop_data.loc[5:,['Borough','County']] = Pop_data.loc[2:,['Borough','County']].shift(1,axis=1)
Pop_data
# Out:
#          Borough                                            County  \
# 0      The Bronx                                             Bronx
# 1       Brooklyn                                             Kings
# 2      Manhattan                                          New York
# 3         Queens                                            Queens
# 4  Staten Island                                          Richmond
# 5            NaN                                  City of New York
# 6            NaN                                 State of New York
# 7            NaN  Sources:[14] and see individual borough articles
#
#   Estimate_2017 GrossDomesticProduct\n square_miles square_km persons_sq_mi  \
# 0     1,432,132               42.695\n       29,200     42.10        109.04
# 1     2,582,830               91.559\n       34,600     70.82        183.42
# 2     1,628,701              600.244\n      360,900     22.83         59.13
# 3     2,278,906               93.310\n       39,600    108.53        281.09
# 4       476,179               14.514\n       30,300     58.37        151.18
# 5     8,398,748                 97,700      842.343    302.64        28,188
# 6    19,745,289                 85,700    1,701.399    47,214         416.4
# 7           NaN                    NaN          NaN       NaN           NaN
#
#    squarekm  persons/sq.mi  persons/km2\n
# 0       NaN            NaN            NaN
# 1       NaN            NaN            NaN
# 2       NaN            NaN            NaN
# 3       NaN            NaN            NaN
# 4       NaN            NaN            NaN
# 5       NaN            NaN            NaN
# 6       NaN            NaN            NaN
# 7       NaN            NaN            NaN

# %%
Pop_data = Pop_data.fillna('')
Pop_data
# Out:
#          Borough                                            County  \
# 0      The Bronx                                             Bronx
# 1       Brooklyn                                             Kings
# 2      Manhattan                                          New York
# 3         Queens                                            Queens
# 4  Staten Island                                          Richmond
# 5                                                 City of New York
# 6                                                State of New York
# 7                 Sources:[14] and see individual borough articles
#
#   Estimate_2017 GrossDomesticProduct\n square_miles square_km persons_sq_mi  \
# 0     1,432,132               42.695\n       29,200     42.10        109.04
# 1     2,582,830               91.559\n       34,600     70.82        183.42
# 2     1,628,701              600.244\n      360,900     22.83         59.13
# 3     2,278,906               93.310\n       39,600    108.53        281.09
# 4       476,179               14.514\n       30,300     58.37        151.18
# 5     8,398,748                 97,700      842.343    302.64        28,188
# 6    19,745,289                 85,700    1,701.399    47,214         416.4
# 7
#
#   squarekm persons/sq.mi persons/km2\n
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
i = Pop_data[((Pop_data.County == 'Sources: [2] and see individual borough articles'))].index
Pop_data.drop(i)
# Out:
#          Borough                                            County  \
# 0      The Bronx                                             Bronx
# 1       Brooklyn                                             Kings
# 2      Manhattan                                          New York
# 3         Queens                                            Queens
# 4  Staten Island                                          Richmond
# 5                                                 City of New York
# 6                                                State of New York
# 7                 Sources:[14] and see individual borough articles
#
#   Estimate_2017 GrossDomesticProduct\n square_miles square_km persons_sq_mi  \
# 0     1,432,132               42.695\n       29,200     42.10        109.04
# 1     2,582,830               91.559\n       34,600     70.82        183.42
# 2     1,628,701              600.244\n      360,900     22.83         59.13
# 3     2,278,906               93.310\n       39,600    108.53        281.09
# 4       476,179               14.514\n       30,300     58.37        151.18
# 5     8,398,748                 97,700      842.343    302.64        28,188
# 6    19,745,289                 85,700    1,701.399    47,214         416.4
# 7
#
#   squarekm persons/sq.mi persons/km2\n
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
Pop_data.to_csv('BON2_POPULATION.csv',index=False)

# %% [markdown]
# <H4>Demographic Data

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/New_York_City').text
soup = BeautifulSoup(website_url,'lxml')
table = soup.find('table',{'class':'wikitable collapsible collapsed mw-collapsible mw-made-collapsible'})
print(soup.prettify())

headers = [header.text for header in table.find_all('th')]

table_rows = table.find_all('tr')        
rows = []
for row in table_rows:
   td = row.find_all('td')
   row = [row.text for row in td]
   rows.append(row)

with open('NYC_DEMO.csv', 'w') as f:
   writer = csv.writer(f)
   writer.writerow(headers)
   writer.writerows(row for row in rows if row)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    New York City - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"XpwyawpAAL0AAwUlRckAAACT","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"New_York_City","wgTitle":"New York City","wgCurRevisionId":951428182,"wgRevisionId":951428182,"wgArticleId":645042,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia articles incorporating a citation from the 1911 Encyclopaedia Britannica with Wikisource reference","Webarchive template wayback links","CS1 maint: ref=harv","Use mdy dates from January 2020","Articles with short description","Pages using multiple image with auto scaled images",
# "Coordinates on Wikidata","Pages using infobox settlement with possible area code list","Articles containing potentially dated statements from 2019","All articles containing potentially dated statements","Use mdy dates from August 2015","Pages using multiple image with manual scaled images","Articles containing potentially dated statements from 2011","All articles with failed verification","Articles with failed verification from March 2019","All articles with unsourced statements","Articles with unsourced statements from March 2019","Articles containing potentially dated statements from July 2019","Articles containing potentially dated statements from 2013","Articles containing potentially dated statements from 2014","Articles containing potentially dated statements from 2012","Articles containing potentially dated statements from 2020","Articles containing potentially dated statements from 2005","Articles with failed verification from February 2020",
# "Articles containing potentially dated statements from 2017","Pages using div col with small parameter","Articles with Curlie links","Wikipedia articles with BNF identifiers","Wikipedia articles with GND identifiers","Wikipedia articles with ISNI identifiers","Wikipedia articles with LCCN identifiers","Wikipedia articles with MusicBrainz area identifiers","Wikipedia articles with NARA identifiers","Wikipedia articles with NDL identifiers","Wikipedia articles with NKC identifiers","Wikipedia articles with SUDOC identifiers","Wikipedia articles with VIAF identifiers","Wikipedia articles with WorldCat identifiers","Pages using the Graph extension","Pages using the Kartographer extension","Boroughs of New York City","New York City","1624 establishments in North America","1624 establishments in the Dutch Empire","1898 establishments in New York (state)","Cities in New York (state)","Cities in the New York metropolitan area","Establishments in New Netherland",
# "Former capitals of the United States","Former state capitals in the United States","Populated coastal places in New York (state)","Populated places established by the Dutch West India Company","Populated places established in 1624","Populated places established in 1898","Populated places on the Hudson River","Port cities and towns of the United States Atlantic coast"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"New_York_City","wgRelevantArticleId":645042,"wgIsProbablyEditable":!1,"wgRelevantPageIsProbablyEditable":!1,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["sysop"],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgRelatedArticles":[
# "Manhattan","List of United States cities by population","New York"],"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgKartographerLiveData":{"_14767c62ca07da1b94a31e3c028d8824ea038bd1":[{"type":"ExternalData","service":"geomask","url":"https://maps.wikimedia.org/geoshape?getgeojson=1\u0026ids=Q60","properties":{"stroke-width":3,"stroke":"#808080","title":"New York City"}}]},"wgCoordinates":{"lat":40.661,"lon":-73.944},"wgWikibaseItemId":"Q60","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.kartographer.style":"ready","ext.cite.styles":"ready","mediawiki.page.gallery.styles":"ready","ext.graph.styles":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","mediawiki.toc.styles":"ready",
# "skins.vector.styles.legacy":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.kartographer.staticframe","ext.cite.ux-enhancements","ext.graph.loader","site","mediawiki.page.startup","skins.vector.js","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.graph.styles%7Cext.kartographer.style%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.page.gallery.styles%7Cmediawiki.toc.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.35.0-wmf.28" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Lower_Manhattan_skyline_-_June_2017.jpg/1200px-Lower_Manhattan_skyline_-_June_2017.jpg" property="og:image"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="/w/index.php?title=Special:RecentChanges&amp;feed=atom" rel="alternate" title="Wikipedia Atom feed" type="application/atom+xml"/>
#   <link href="https://en.wikipedia.org/wiki/New_York_City" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#   <!--[if lt IE 9]><script src="/w/resources/lib/html5shiv/html5shiv.js"></script><![endif]-->
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-New_York_City rootpage-New_York_City skin-vector action-view">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div class="mw-body-content" id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators mw-body-content">
#    </div>
#    <h1 class="firstHeading" id="firstHeading" lang="en">
#     New York City
#    </h1>
#    <div class="mw-body-content" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#p-search">
#      Jump to search
#     </a>
#     <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <div class="hatnote navigation-not-searchable" role="note">
#        "NYC" and "New York, New York" redirect here. For other uses, see
#        <a class="mw-disambig" href="/wiki/New_York_City_(disambiguation)" title="New York City (disambiguation)">
#         New York City (disambiguation)
#        </a>
#        ;
#        <a class="mw-disambig" href="/wiki/NYC_(disambiguation)" title="NYC (disambiguation)">
#         NYC (disambiguation)
#        </a>
#        ; and
#        <a class="mw-disambig" href="/wiki/New_York,_New_York_(disambiguation)" title="New York, New York (disambiguation)">
#         New York, New York (disambiguation)
#        </a>
#        .
#       </div>
#       <p class="mw-empty-elt">
#       </p>
#       <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">
#        Largest city in the United States
#       </div>
#       <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">
#        City
#       </div>
#       <table class="infobox geography vcard" style="width:22em;width:23em">
#        <tbody>
#         <tr>
#          <th colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-size:1.25em; white-space:nowrap">
#           <div class="fn org" style="display:inline">
#            New York
#           </div>
#          </th>
#         </tr>
#         <tr>
#          <td colspan="2" style="text-align:center;background-color:#cddeff; font-weight:bold;">
#           <div class="category">
#            <a class="mw-redirect" href="/wiki/City_(New_York)" title="City (New York)">
#             City
#            </a>
#           </div>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <td colspan="2" style="text-align:center">
#           <style data-mw-deduplicate="TemplateStyles:r923042769/mw-parser-output/.tmulti">
#            .mw-parser-output .tmulti .thumbinner{display:flex;flex-direction:column}.mw-parser-output .tmulti .trow{display:flex;flex-direction:row;clear:left;flex-wrap:wrap;width:100%;box-sizing:border-box}.mw-parser-output .tmulti .tsingle{margin:1px;float:left}.mw-parser-output .tmulti .theader{clear:both;font-weight:bold;text-align:center;align-self:center;background-color:transparent;width:100%}.mw-parser-output .tmulti .thumbcaption{text-align:left;background-color:transparent}.mw-parser-output .tmulti .thumbcaption-center{text-align:center;background-color:transparent}.mw-parser-output .tmulti .text-align-left{text-align:left}.mw-parser-output .tmulti .text-align-right{text-align:right}.mw-parser-output .tmulti .text-align-center{text-align:center}@media all and (max-width:720px){.mw-parser-output .tmulti .thumbinner{width:100%!important;box-sizing:border-box;max-width:none!important;align-items:center}.mw-parser-output .tmulti .trow{justify-content:center}.mw-parser-output .tmulti .tsingle{float:none!important;max-width:100%!important;box-sizing:border-box;text-align:center}.mw-parser-output .tmulti .thumbcaption{text-align:center}}
#           </style>
#           <div class="thumb tmulti tnone center">
#            <div class="thumbinner" style="width:282px;max-width:282px;border:none">
#             <div class="trow">
#              <div class="tsingle" style="width:280px;max-width:280px">
#               <div class="thumbimage" style="border:1;;height:106px;overflow:hidden">
#                <a class="image" href="/wiki/File:Lower_Manhattan_skyline_-_June_2017.jpg">
#                 <img alt="" data-file-height="3625" data-file-width="9507" decoding="async" height="106" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Lower_Manhattan_skyline_-_June_2017.jpg/278px-Lower_Manhattan_skyline_-_June_2017.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Lower_Manhattan_skyline_-_June_2017.jpg/417px-Lower_Manhattan_skyline_-_June_2017.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Lower_Manhattan_skyline_-_June_2017.jpg/556px-Lower_Manhattan_skyline_-_June_2017.jpg 2x" width="278"/>
#                </a>
#               </div>
#              </div>
#             </div>
#             <div class="trow">
#              <div class="tsingle" style="width:104px;max-width:104px">
#               <div class="thumbimage" style="border:1;;height:116px;overflow:hidden">
#                <a class="image" href="/wiki/File:Central_park_pond.jpg">
#                 <img alt="" data-file-height="1920" data-file-width="1676" decoding="async" height="117" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/94/Central_park_pond.jpg/102px-Central_park_pond.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/94/Central_park_pond.jpg/153px-Central_park_pond.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/94/Central_park_pond.jpg/204px-Central_park_pond.jpg 2x" width="102"/>
#                </a>
#               </div>
#              </div>
#              <div class="tsingle" style="width:92px;max-width:92px">
#               <div class="thumbimage" style="border:1;;height:116px;overflow:hidden">
#                <a class="image" href="/wiki/File:Unisphere_Flushing_Meadows_Queens.jpg">
#                 <img alt="" data-file-height="3300" data-file-width="2550" decoding="async" height="116" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/50/Unisphere_Flushing_Meadows_Queens.jpg/90px-Unisphere_Flushing_Meadows_Queens.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/50/Unisphere_Flushing_Meadows_Queens.jpg/135px-Unisphere_Flushing_Meadows_Queens.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/50/Unisphere_Flushing_Meadows_Queens.jpg/180px-Unisphere_Flushing_Meadows_Queens.jpg 2x" width="90"/>
#                </a>
#               </div>
#              </div>
#              <div class="tsingle" style="width:80px;max-width:80px">
#               <div class="thumbimage" style="border:1;;height:116px;overflow:hidden">
#                <a class="image" href="/wiki/File:Brooklyn_Bridge,_west_tower_(7433306334).jpg">
#                 <img alt="" data-file-height="5184" data-file-width="3456" decoding="async" height="117" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Brooklyn_Bridge%2C_west_tower_%287433306334%29.jpg/78px-Brooklyn_Bridge%2C_west_tower_%287433306334%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Brooklyn_Bridge%2C_west_tower_%287433306334%29.jpg/117px-Brooklyn_Bridge%2C_west_tower_%287433306334%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Brooklyn_Bridge%2C_west_tower_%287433306334%29.jpg/156px-Brooklyn_Bridge%2C_west_tower_%287433306334%29.jpg 2x" width="78"/>
#                </a>
#               </div>
#              </div>
#             </div>
#             <div class="trow">
#              <div class="tsingle" style="width:114px;max-width:114px">
#               <div class="thumbimage" style="border:1;;height:148px;overflow:hidden">
#                <a class="image" href="/wiki/File:LadyLiberty02.jpg">
#                 <img alt="" data-file-height="4032" data-file-width="3024" decoding="async" height="149" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fd/LadyLiberty02.jpg/112px-LadyLiberty02.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fd/LadyLiberty02.jpg/168px-LadyLiberty02.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fd/LadyLiberty02.jpg/224px-LadyLiberty02.jpg 2x" width="112"/>
#                </a>
#               </div>
#              </div>
#              <div class="tsingle" style="width:164px;max-width:164px">
#               <div class="thumbimage" style="border:1;;height:148px;overflow:hidden">
#                <a class="image" href="/wiki/File:Times_square_night.jpg">
#                 <img alt="" data-file-height="2241" data-file-width="2448" decoding="async" height="148" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Times_square_night.jpg/162px-Times_square_night.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Times_square_night.jpg/243px-Times_square_night.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3d/Times_square_night.jpg/324px-Times_square_night.jpg 2x" width="162"/>
#                </a>
#               </div>
#              </div>
#             </div>
#             <div class="trow">
#              <div class="tsingle" style="width:192px;max-width:192px">
#               <div class="thumbimage" style="border:1;;height:126px;overflow:hidden">
#                <a class="image" href="/wiki/File:Joe-taylor--MxVssjbvTY-unsplash.jpg">
#                 <img alt="" data-file-height="3376" data-file-width="5065" decoding="async" height="127" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/54/Joe-taylor--MxVssjbvTY-unsplash.jpg/190px-Joe-taylor--MxVssjbvTY-unsplash.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/54/Joe-taylor--MxVssjbvTY-unsplash.jpg/285px-Joe-taylor--MxVssjbvTY-unsplash.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/54/Joe-taylor--MxVssjbvTY-unsplash.jpg/380px-Joe-taylor--MxVssjbvTY-unsplash.jpg 2x" width="190"/>
#                </a>
#               </div>
#              </div>
#              <div class="tsingle" style="width:86px;max-width:86px">
#               <div class="thumbimage" style="border:1;;height:126px;overflow:hidden">
#                <a class="image" href="/wiki/File:Manhattan_Bridge_2_(6214831091).jpg">
#                 <img alt="" data-file-height="4752" data-file-width="3168" decoding="async" height="126" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Manhattan_Bridge_2_%286214831091%29.jpg/84px-Manhattan_Bridge_2_%286214831091%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Manhattan_Bridge_2_%286214831091%29.jpg/126px-Manhattan_Bridge_2_%286214831091%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/34/Manhattan_Bridge_2_%286214831091%29.jpg/168px-Manhattan_Bridge_2_%286214831091%29.jpg 2x" width="84"/>
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div style="padding:0.4em 0 0 0;">
#            From top, left to right:
#            <a href="/wiki/Lower_Manhattan" title="Lower Manhattan">
#             Lower Manhattan
#            </a>
#            ,
#            <a href="/wiki/Central_Park" title="Central Park">
#             Central Park
#            </a>
#            , the
#            <a href="/wiki/Unisphere" title="Unisphere">
#             Unisphere
#            </a>
#            , the
#            <a href="/wiki/Brooklyn_Bridge" title="Brooklyn Bridge">
#             Brooklyn Bridge
#            </a>
#            ,
#            <a href="/wiki/Statue_of_Liberty" title="Statue of Liberty">
#             Statue of Liberty
#            </a>
#            ,
#            <a href="/wiki/Times_Square" title="Times Square">
#             Times Square
#            </a>
#            ,
#            <a href="/wiki/Midtown_Manhattan" title="Midtown Manhattan">
#             Midtown Manhattan
#            </a>
#            ,
#            <a href="/wiki/Manhattan_Bridge" title="Manhattan Bridge">
#             Manhattan Bridge
#            </a>
#           </div>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <td class="maptable" colspan="2" style="text-align:center">
#           <div style="display:table; width:100%; background:none;">
#            <div style="display:table-row">
#             <div style="display:table-cell;vertical-align:middle; text-align:center;">
#              <a class="image" href="/wiki/File:Flag_of_New_York_City.svg" title="Flag of New York">
#               <img alt="Flag of New York" class="thumbborder" data-file-height="300" data-file-width="500" decoding="async" height="60" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Flag_of_New_York_City.svg/100px-Flag_of_New_York_City.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Flag_of_New_York_City.svg/150px-Flag_of_New_York_City.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Flag_of_New_York_City.svg/200px-Flag_of_New_York_City.svg.png 2x" width="100"/>
#              </a>
#              <br/>
#              <a class="mw-redirect" href="/wiki/Flag_of_New_York_City" title="Flag of New York City">
#               Flag
#              </a>
#             </div>
#             <div style="display:table-cell;vertical-align:middle; text-align:center;">
#              <a class="image" href="/wiki/File:Seal_of_New_York_City_BW.svg" title="Official seal of New York">
#               <img alt="Official seal of New York" data-file-height="450" data-file-width="419" decoding="async" height="107" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/61/Seal_of_New_York_City_BW.svg/100px-Seal_of_New_York_City_BW.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/61/Seal_of_New_York_City_BW.svg/150px-Seal_of_New_York_City_BW.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/61/Seal_of_New_York_City_BW.svg/200px-Seal_of_New_York_City_BW.svg.png 2x" width="100"/>
#              </a>
#              <br/>
#              <a href="/wiki/Seal_of_New_York_City" title="Seal of New York City">
#               Seal
#              </a>
#             </div>
#            </div>
#            <div style="display:table-row">
#            </div>
#           </div>
#           <div style="display:table; width:100%; background:none;">
#            <div style="display:table-row">
#             <div style="display:table-cell;vertical-align:middle; text-align:center;">
#              <a class="image" href="/wiki/File:NYC_Logo_Wolff_Olins.svg" title="Official logo of New York">
#               <img alt="Official logo of New York" data-file-height="29" data-file-width="88" decoding="async" height="33" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/NYC_Logo_Wolff_Olins.svg/100px-NYC_Logo_Wolff_Olins.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/NYC_Logo_Wolff_Olins.svg/150px-NYC_Logo_Wolff_Olins.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/09/NYC_Logo_Wolff_Olins.svg/200px-NYC_Logo_Wolff_Olins.svg.png 2x" width="100"/>
#              </a>
#              <br/>
#              <a href="/wiki/Wordmark" title="Wordmark">
#               Wordmark
#              </a>
#             </div>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <td colspan="2" style="text-align:center">
#           Nickname(s):
#           <div class="nickname" style="display:inline">
#            <i>
#             See
#             <a href="/wiki/Nicknames_of_New_York_City" title="Nicknames of New York City">
#              Nicknames of New York City
#             </a>
#            </i>
#           </div>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <td colspan="2" style="text-align:center">
#           <a class="mw-kartographer-map mw-kartographer-container center" data-height="270" data-lat="40.7" data-lon="-73.944" data-mw="interface" data-overlays='["_14767c62ca07da1b94a31e3c028d8824ea038bd1"]' data-style="osm-intl" data-width="290" data-zoom="9" href="/wiki/Special:Map/9/40.7/-73.944/en" style="width: 290px; height: 270px;">
#            <img alt="" decoding="async" height="270" src="https://maps.wikimedia.org/img/osm-intl,9,40.7,-73.944,290x270.png?lang=en&amp;domain=en.wikipedia.org&amp;title=New+York+City&amp;groups=_14767c62ca07da1b94a31e3c028d8824ea038bd1" srcset="https://maps.wikimedia.org/img/osm-intl,9,40.7,-73.944,290x270@2x.png?lang=en&amp;domain=en.wikipedia.org&amp;title=New+York+City&amp;groups=_14767c62ca07da1b94a31e3c028d8824ea038bd1 2x" width="290"/>
#           </a>
#           <div style="padding:0.3em 0 0 0;">
#            Interactive map outlining New York City
#           </div>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <td colspan="2" style="text-align:center">
#           <div class="switcher-container">
#            <div class="center">
#             <div style="width:290px;float:none;clear:both;margin-left:auto;margin-right:auto">
#              <div style="width:290px;padding:0">
#               <div style="position:relative;width:290px">
#                <a class="image" href="/wiki/File:USA_New_York_location_map.svg" title="New York is located in New York">
#                 <img alt="New York is located in New York" data-file-height="1276" data-file-width="1569" decoding="async" height="236" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8d/USA_New_York_location_map.svg/290px-USA_New_York_location_map.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8d/USA_New_York_location_map.svg/435px-USA_New_York_location_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8d/USA_New_York_location_map.svg/580px-USA_New_York_location_map.svg.png 2x" width="290"/>
#                </a>
#                <div style="position:absolute;top:92.78%;left:72.964%">
#                 <div style="position:absolute;left:-3px;top:-3px;line-height:0">
#                  <img alt="New York" data-file-height="64" data-file-width="64" decoding="async" height="6" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/6px-Red_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/9px-Red_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/12px-Red_pog.svg.png 2x" title="New York" width="6"/>
#                 </div>
#                 <div style="font-size:90%;line-height:110%;position:absolute;width:6em;top:-0.75em;right:4px;text-align:right">
#                  <div style="display:inline;padding:1px;float:right">
#                   New York
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div>
#                Location within the state of New York
#               </div>
#               <span class="switcher-label" style="display:none">
#                Show map of New York
#               </span>
#              </div>
#             </div>
#            </div>
#            <div class="center">
#             <div style="width:290px;float:none;clear:both;margin-left:auto;margin-right:auto">
#              <div style="width:290px;padding:0">
#               <div style="position:relative;width:290px">
#                <a class="image" href="/wiki/File:Usa_edcp_relief_location_map.png" title="New York is located in the United States">
#                 <img alt="New York is located in the United States" data-file-height="731" data-file-width="1181" decoding="async" height="180" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Usa_edcp_relief_location_map.png/290px-Usa_edcp_relief_location_map.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Usa_edcp_relief_location_map.png/435px-Usa_edcp_relief_location_map.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Usa_edcp_relief_location_map.png/580px-Usa_edcp_relief_location_map.png 2x" width="290"/>
#                </a>
#                <div style="position:absolute;top:35.706%;left:85.831%">
#                 <div style="position:absolute;left:-3px;top:-3px;line-height:0">
#                  <img alt="New York" data-file-height="64" data-file-width="64" decoding="async" height="6" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/6px-Red_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/9px-Red_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/12px-Red_pog.svg.png 2x" title="New York" width="6"/>
#                 </div>
#                 <div style="font-size:90%;line-height:110%;position:absolute;width:6em;top:-0.75em;right:4px;text-align:right">
#                  <div style="display:inline;padding:1px;float:right">
#                   New York
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div>
#                Location within the United States
#               </div>
#               <span class="switcher-label" style="display:none">
#                Show map of the United States
#               </span>
#              </div>
#             </div>
#            </div>
#            <div class="center">
#             <div style="width:290px;float:none;clear:both;margin-left:auto;margin-right:auto">
#              <div style="width:290px;padding:0">
#               <div style="position:relative;width:290px">
#                <a class="image" href="/wiki/File:North_America_laea_relief_location_map.jpg" title="New York is located in North America">
#                 <img alt="New York is located in North America" data-file-height="1185" data-file-width="1181" decoding="async" height="291" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/North_America_laea_relief_location_map.jpg/290px-North_America_laea_relief_location_map.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/49/North_America_laea_relief_location_map.jpg/435px-North_America_laea_relief_location_map.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/49/North_America_laea_relief_location_map.jpg/580px-North_America_laea_relief_location_map.jpg 2x" width="290"/>
#                </a>
#                <div style="position:absolute;top:54.358%;left:73.474%">
#                 <div style="position:absolute;left:-3px;top:-3px;line-height:0">
#                  <img alt="New York" data-file-height="64" data-file-width="64" decoding="async" height="6" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/6px-Red_pog.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/9px-Red_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Red_pog.svg/12px-Red_pog.svg.png 2x" title="New York" width="6"/>
#                 </div>
#                 <div style="font-size:90%;line-height:110%;position:absolute;width:6em;top:-0.75em;right:4px;text-align:right">
#                  <div style="display:inline;padding:1px;float:right">
#                   New York
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div>
#                Location within North America
#               </div>
#               <span class="switcher-label" style="display:none">
#                Show map of North America
#               </span>
#              </div>
#             </div>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr class="mergedbottomrow">
#          <td colspan="2" style="text-align:center">
#           Coordinates:
#           <span class="plainlinks nourlexpansion">
#            <a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=New_York_City&amp;params=40.661_N_73.944_W_region:US-NY_type:city(8175133)">
#             <span class="geo-default">
#              <span class="geo-dms" title="Maps, aerial photos, and other data for this location">
#               <span class="latitude">
#                40°39′40″N
#               </span>
#               <span class="longitude">
#                73°56′38″W
#               </span>
#              </span>
#             </span>
#             <span class="geo-multi-punct">
#              ﻿ / ﻿
#             </span>
#             <span class="geo-nondefault">
#              <span class="geo-dec" title="Maps, aerial photos, and other data for this location">
#               40.661°N 73.944°W
#              </span>
#              <span style="display:none">
#               ﻿ /
#               <span class="geo">
#                40.661; -73.944
#               </span>
#              </span>
#             </span>
#            </a>
#           </span>
#           <span style="font-size: small;">
#            <span id="coordinates">
#             <a href="/wiki/Geographic_coordinate_system" title="Geographic coordinate system">
#              Coordinates
#             </a>
#             :
#             <span class="plainlinks nourlexpansion">
#              <a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=New_York_City&amp;params=40.661_N_73.944_W_region:US-NY_type:city(8175133)">
#               <span class="geo-default">
#                <span class="geo-dms" title="Maps, aerial photos, and other data for this location">
#                 <span class="latitude">
#                  40°39′40″N
#                 </span>
#                 <span class="longitude">
#                  73°56′38″W
#                 </span>
#                </span>
#               </span>
#               <span class="geo-multi-punct">
#                ﻿ / ﻿
#               </span>
#               <span class="geo-nondefault">
#                <span class="geo-dec" title="Maps, aerial photos, and other data for this location">
#                 40.661°N 73.944°W
#                </span>
#                <span style="display:none">
#                 ﻿ /
#                 <span class="geo">
#                  40.661; -73.944
#                 </span>
#                </span>
#               </span>
#              </a>
#             </span>
#            </span>
#           </span>
#           <sup class="reference" id="cite_ref-GR1_1-0">
#            <a href="#cite_note-GR1-1">
#             [1]
#            </a>
#           </sup>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th scope="row">
#           Country
#          </th>
#          <td>
#           <span class="nowrap">
#            <span class="flagicon">
#             <img alt="" class="thumbborder" data-file-height="650" data-file-width="1235" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" width="23"/>
#            </span>
#            <a href="/wiki/United_States" title="United States">
#             United States
#            </a>
#           </span>
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           State
#          </th>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="450" data-file-width="900" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_New_York.svg/23px-Flag_of_New_York.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_New_York.svg/35px-Flag_of_New_York.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_New_York.svg/46px-Flag_of_New_York.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/New_York_(state)" title="New York (state)">
#            New York
#           </a>
#           <hr/>
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           <a href="/wiki/List_of_regions_of_the_United_States" title="List of regions of the United States">
#            Region
#           </a>
#          </th>
#          <td>
#           <a href="/wiki/Mid-Atlantic_(United_States)" title="Mid-Atlantic (United States)">
#            Mid-Atlantic
#           </a>
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           <a href="/wiki/County_(United_States)" title="County (United States)">
#            Constituent counties
#           </a>
#           (
#           <a href="/wiki/Boroughs_of_New_York_City" title="Boroughs of New York City">
#            boroughs
#           </a>
#           )
#          </th>
#          <td>
#           <a href="/wiki/The_Bronx" title="The Bronx">
#            Bronx (The Bronx)
#           </a>
#           <br/>
#           <a href="/wiki/Brooklyn" title="Brooklyn">
#            Kings (Brooklyn)
#           </a>
#           <br/>
#           <a href="/wiki/Manhattan" title="Manhattan">
#            New York (Manhattan)
#           </a>
#           <br/>
#           <a href="/wiki/Queens" title="Queens">
#            Queens (Queens)
#           </a>
#           <br/>
#           <a href="/wiki/Staten_Island" title="Staten Island">
#            Richmond (Staten Island)
#           </a>
#           <hr/>
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           <a href="/wiki/Colony" title="Colony">
#            Historic colonies
#           </a>
#          </th>
#          <td>
#           <a href="/wiki/New_Netherland" title="New Netherland">
#            New Netherland
#           </a>
#           <br/>
#           <a href="/wiki/Province_of_New_York" title="Province of New York">
#            Province of New York
#           </a>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th scope="row">
#           Settled
#          </th>
#          <td>
#           1624
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           <a href="/wiki/City_of_Greater_New_York" title="City of Greater New York">
#            Consolidated
#           </a>
#          </th>
#          <td>
#           1898
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           <a href="/wiki/Namesake" title="Namesake">
#            Named for
#           </a>
#          </th>
#          <td>
#           <a href="/wiki/James_II_of_England" title="James II of England">
#            James, Duke of York
#           </a>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th colspan="2" style="text-align:center;text-align:left">
#           Government
#           <div style="font-weight:normal;display:inline;">
#           </div>
#          </th>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           • Type
#          </th>
#          <td>
#           <a href="/wiki/Mayor%E2%80%93council_government" title="Mayor–council government">
#            Mayor–Council
#           </a>
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           • Body
#          </th>
#          <td class="agent">
#           <a href="/wiki/New_York_City_Council" title="New York City Council">
#            New York City Council
#           </a>
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           •
#           <a href="/wiki/Mayor_of_New_York_City" title="Mayor of New York City">
#            Mayor
#           </a>
#          </th>
#          <td>
#           <a href="/wiki/Bill_de_Blasio" title="Bill de Blasio">
#            Bill de Blasio
#           </a>
#           (
#           <a href="/wiki/Democratic_Party_(United_States)" title="Democratic Party (United States)">
#            D
#           </a>
#           )
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th colspan="2" style="text-align:center;text-align:left">
#           Area
#           <div style="font-weight:normal;display:inline;">
#            <sup class="reference" id="cite_ref-GR1_1-1">
#             <a href="#cite_note-GR1-1">
#              [1]
#             </a>
#            </sup>
#           </div>
#          </th>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           • Total
#          </th>
#          <td>
#           468.484 sq mi (1,213.37 km
#           <sup>
#            2
#           </sup>
#           )
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           • Land
#          </th>
#          <td>
#           302.643 sq mi (783.84 km
#           <sup>
#            2
#           </sup>
#           )
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           • Water
#          </th>
#          <td>
#           165.841 sq mi (429.53 km
#           <sup>
#            2
#           </sup>
#           )
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           • Metro
#           <div style="font-weight:normal;display:inline;">
#           </div>
#          </th>
#          <td>
#           13,318 sq mi (34,490 km
#           <sup>
#            2
#           </sup>
#           )
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th scope="row">
#           Elevation
#           <div style="font-weight:normal;display:inline;">
#            <sup class="reference" id="cite_ref-GR3_2-0">
#             <a href="#cite_note-GR3-2">
#              [2]
#             </a>
#            </sup>
#           </div>
#          </th>
#          <td>
#           33 ft (10 m)
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th colspan="2" style="text-align:center;text-align:left">
#           Population
#           <div style="font-weight:normal;display:inline;">
#            <span class="nowrap">
#            </span>
#            (
#            <a href="/wiki/2010_United_States_Census" title="2010 United States Census">
#             2010
#            </a>
#            )
#            <sup class="reference" id="cite_ref-Census2010_5-0">
#             <a href="#cite_note-Census2010-5">
#              [5]
#             </a>
#            </sup>
#           </div>
#          </th>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           • Total
#          </th>
#          <td>
#           8,175,133
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           • Estimate
#           <div style="font-weight:normal;display:inline;">
#            (2018)
#            <sup class="reference" id="cite_ref-2018Estimate_6-0">
#             <a href="#cite_note-2018Estimate-6">
#              [6]
#             </a>
#            </sup>
#           </div>
#          </th>
#          <td>
#           8,398,748
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           • Rank
#          </th>
#          <td>
#           <a href="/wiki/List_of_United_States_cities_by_population" title="List of United States cities by population">
#            1st in the U.S.
#           </a>
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           • Density
#          </th>
#          <td>
#           27,751/sq mi (10,715/km
#           <sup>
#            2
#           </sup>
#           )
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           •
#           <a href="/wiki/Metropolitan_statistical_area" title="Metropolitan statistical area">
#            MSA (2018)
#           </a>
#           <div style="font-weight:normal;display:inline;">
#           </div>
#          </th>
#          <td>
#           19,979,477
#           <sup class="reference" id="cite_ref-MetroEst_3-0">
#            <a href="#cite_note-MetroEst-3">
#             [3]
#            </a>
#           </sup>
#           (
#           <a href="/wiki/List_of_metropolitan_statistical_areas" title="List of metropolitan statistical areas">
#            1st
#           </a>
#           )
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           •
#           <a href="/wiki/New_York_metropolitan_area" title="New York metropolitan area">
#            CSA (2018)
#           </a>
#           <div style="font-weight:normal;display:inline;">
#           </div>
#          </th>
#          <td>
#           22,679,948
#           <sup class="reference" id="cite_ref-CombinedEst_4-0">
#            <a href="#cite_note-CombinedEst-4">
#             [4]
#            </a>
#           </sup>
#           (
#           <a class="mw-redirect" href="/wiki/List_of_Combined_Statistical_Areas" title="List of Combined Statistical Areas">
#            1st
#           </a>
#           )
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th scope="row">
#           <a href="/wiki/Demonym" title="Demonym">
#            Demonym(s)
#           </a>
#          </th>
#          <td>
#           New Yorker
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th scope="row">
#           <a href="/wiki/Time_zone" title="Time zone">
#            Time zone
#           </a>
#          </th>
#          <td>
#           <a href="/wiki/UTC%E2%88%9205:00" title="UTC−05:00">
#            UTC−05:00
#           </a>
#           (
#           <a href="/wiki/Eastern_Time_Zone" title="Eastern Time Zone">
#            EST
#           </a>
#           )
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           <span style="white-space:nowrap">
#            • Summer (
#            <a href="/wiki/Daylight_saving_time" title="Daylight saving time">
#             DST
#            </a>
#            )
#           </span>
#          </th>
#          <td>
#           <a href="/wiki/UTC%E2%88%9204:00" title="UTC−04:00">
#            UTC−04:00
#           </a>
#           (
#           <a href="/wiki/Eastern_Time_Zone" title="Eastern Time Zone">
#            EDT
#           </a>
#           )
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th scope="row">
#           <a href="/wiki/ZIP_Code" title="ZIP Code">
#            ZIP Codes
#           </a>
#          </th>
#          <td class="adr">
#           <div class="postal-code">
#            100xx–104xx, 11004–05, 111xx–114xx, 116xx
#           </div>
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           <a href="/wiki/Telephone_numbering_plan" title="Telephone numbering plan">
#            Area code(s)
#           </a>
#          </th>
#          <td>
#           <a href="/wiki/Area_codes_212,_646,_and_332" title="Area codes 212, 646, and 332">
#            212/646/332
#           </a>
#           ,
#           <a href="/wiki/Area_codes_718,_347,_and_929" title="Area codes 718, 347, and 929">
#            718/347/929
#           </a>
#           ,
#           <a href="/wiki/Area_code_917" title="Area code 917">
#            917
#           </a>
#          </td>
#         </tr>
#         <tr class="mergedtoprow">
#          <th scope="row">
#           <a href="/wiki/Federal_Information_Processing_Standards" title="Federal Information Processing Standards">
#            FIPS code
#           </a>
#          </th>
#          <td>
#           36-51000
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           <a href="/wiki/Geographic_Names_Information_System" title="Geographic Names Information System">
#            GNIS
#           </a>
#           feature ID
#          </th>
#          <td>
#           975772
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           Major airports
#          </th>
#          <td>
#           <a href="/wiki/John_F._Kennedy_International_Airport" title="John F. Kennedy International Airport">
#            John F. Kennedy International Airport
#           </a>
#           ,
#           <a href="/wiki/Newark_Liberty_International_Airport" title="Newark Liberty International Airport">
#            Newark Liberty International Airport
#           </a>
#           ,
#           <a href="/wiki/LaGuardia_Airport" title="LaGuardia Airport">
#            LaGuardia Airport
#           </a>
#          </td>
#         </tr>
#         <tr class="mergedrow">
#          <th scope="row">
#           <a href="/wiki/Commuter_rail" title="Commuter rail">
#            Commuter rail
#           </a>
#          </th>
#          <td>
#           <a class="mw-redirect" href="/wiki/LIRR" title="LIRR">
#            LIRR
#           </a>
#           ,
# ...
#          Srpskohrvatski / српскохрватски
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fi badge-Q17559452 badge-recommendedarticle" title="recommended article">
#         <a class="interlanguage-link-target" href="https://fi.wikipedia.org/wiki/New_York" hreflang="fi" lang="fi" title="New York – Finnish">
#          Suomi
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sv">
#         <a class="interlanguage-link-target" href="https://sv.wikipedia.org/wiki/New_York" hreflang="sv" lang="sv" title="New York – Swedish">
#          Svenska
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tl">
#         <a class="interlanguage-link-target" href="https://tl.wikipedia.org/wiki/Lungsod_ng_Bagong_York" hreflang="tl" lang="tl" title="Lungsod ng Bagong York – Tagalog">
#          Tagalog
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ta">
#         <a class="interlanguage-link-target" href="https://ta.wikipedia.org/wiki/%E0%AE%A8%E0%AE%BF%E0%AE%AF%E0%AF%82%E0%AE%AF%E0%AE%BE%E0%AE%B0%E0%AF%8D%E0%AE%95%E0%AF%8D%E0%AE%95%E0%AF%81_%E0%AE%A8%E0%AE%95%E0%AE%B0%E0%AE%AE%E0%AF%8D" hreflang="ta" lang="ta" title="நியூயார்க்கு நகரம் – Tamil">
#          தமிழ்
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-kab">
#         <a class="interlanguage-link-target" href="https://kab.wikipedia.org/wiki/New_York" hreflang="kab" lang="kab" title="New York – Kabyle">
#          Taqbaylit
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-roa-tara">
#         <a class="interlanguage-link-target" href="https://roa-tara.wikipedia.org/wiki/Nu%C3%A8ve_York" hreflang="nap-x-tara" lang="nap-x-tara" title="Nuève York – Tarantino">
#          Tarandíne
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tt">
#         <a class="interlanguage-link-target" href="https://tt.wikipedia.org/wiki/%D0%9D%D1%8C%D1%8E-%D0%99%D0%BE%D1%80%D0%BA" hreflang="tt" lang="tt" title="Нью-Йорк – Tatar">
#          Татарча/tatarça
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-te">
#         <a class="interlanguage-link-target" href="https://te.wikipedia.org/wiki/%E0%B0%A8%E0%B1%8D%E0%B0%AF%E0%B1%82%E0%B0%AF%E0%B0%BE%E0%B0%B0%E0%B1%8D%E0%B0%95%E0%B1%8D" hreflang="te" lang="te" title="న్యూయార్క్ – Telugu">
#          తెలుగు
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-th">
#         <a class="interlanguage-link-target" href="https://th.wikipedia.org/wiki/%E0%B8%99%E0%B8%84%E0%B8%A3%E0%B8%99%E0%B8%B4%E0%B8%A7%E0%B8%A2%E0%B8%AD%E0%B8%A3%E0%B9%8C%E0%B8%81" hreflang="th" lang="th" title="นครนิวยอร์ก – Thai">
#          ไทย
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tg">
#         <a class="interlanguage-link-target" href="https://tg.wikipedia.org/wiki/%D0%9D%D1%8E-%D0%99%D0%BE%D1%80%D0%BA" hreflang="tg" lang="tg" title="Ню-Йорк – Tajik">
#          Тоҷикӣ
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tr">
#         <a class="interlanguage-link-target" href="https://tr.wikipedia.org/wiki/New_York" hreflang="tr" lang="tr" title="New York – Turkish">
#          Türkçe
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tk">
#         <a class="interlanguage-link-target" href="https://tk.wikipedia.org/wiki/N%C3%BDu-%C3%9Dork_%C5%9F%C3%A4heri" hreflang="tk" lang="tk" title="Nýu-Ýork şäheri – Turkmen">
#          Türkmençe
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tw">
#         <a class="interlanguage-link-target" href="https://tw.wikipedia.org/wiki/New_York" hreflang="tw" lang="tw" title="New York – Twi">
#          Twi
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-udm">
#         <a class="interlanguage-link-target" href="https://udm.wikipedia.org/wiki/%D0%9D%D1%8C%D1%8E-%D0%99%D0%BE%D1%80%D0%BA" hreflang="udm" lang="udm" title="Нью-Йорк – Udmurt">
#          Удмурт
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-bug">
#         <a class="interlanguage-link-target" href="https://bug.wikipedia.org/wiki/Kuta_New_York" hreflang="bug" lang="bug" title="Kuta New York – Buginese">
#          ᨅᨔ ᨕᨘᨁᨗ
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-uk">
#         <a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/%D0%9D%D1%8C%D1%8E-%D0%99%D0%BE%D1%80%D0%BA" hreflang="uk" lang="uk" title="Нью-Йорк – Ukrainian">
#          Українська
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ur">
#         <a class="interlanguage-link-target" href="https://ur.wikipedia.org/wiki/%D9%86%DB%8C%D9%88_%DB%8C%D8%A7%D8%B1%DA%A9_%D8%B4%DB%81%D8%B1" hreflang="ur" lang="ur" title="نیو یارک شہر – Urdu">
#          اردو
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ug">
#         <a class="interlanguage-link-target" href="https://ug.wikipedia.org/wiki/Nyu_York_Shehiri" hreflang="ug" lang="ug" title="Nyu York Shehiri – Uyghur">
#          ئۇيغۇرچە / Uyghurche
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-za">
#         <a class="interlanguage-link-target" href="https://za.wikipedia.org/wiki/Niujyoz" hreflang="za" lang="za" title="Niujyoz – Zhuang">
#          Vahcuengh
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vec">
#         <a class="interlanguage-link-target" href="https://vec.wikipedia.org/wiki/New_York" hreflang="vec" lang="vec" title="New York – Venetian">
#          Vèneto
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vep">
#         <a class="interlanguage-link-target" href="https://vep.wikipedia.org/wiki/Nju_Jork" hreflang="vep" lang="vep" title="Nju Jork – Veps">
#          Vepsän kel’
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vi badge-Q17437798 badge-goodarticle" title="good article">
#         <a class="interlanguage-link-target" href="https://vi.wikipedia.org/wiki/Th%C3%A0nh_ph%E1%BB%91_New_York" hreflang="vi" lang="vi" title="Thành phố New York – Vietnamese">
#          Tiếng Việt
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vo">
#         <a class="interlanguage-link-target" href="https://vo.wikipedia.org/wiki/New_York_(zif)" hreflang="vo" lang="vo" title="New York (zif) – Volapük">
#          Volapük
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fiu-vro">
#         <a class="interlanguage-link-target" href="https://fiu-vro.wikipedia.org/wiki/New_York" hreflang="vro" lang="vro" title="New York – Võro">
#          Võro
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh-classical">
#         <a class="interlanguage-link-target" href="https://zh-classical.wikipedia.org/wiki/%E7%B4%90%E7%B4%84%E5%B8%82" hreflang="lzh" lang="lzh" title="紐約市 – Classical Chinese">
#          文言
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-war">
#         <a class="interlanguage-link-target" href="https://war.wikipedia.org/wiki/Syudad_han_New_York" hreflang="war" lang="war" title="Syudad han New York – Waray">
#          Winaray
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-wuu">
#         <a class="interlanguage-link-target" href="https://wuu.wikipedia.org/wiki/%E7%BA%BD%E7%BA%A6%E5%B8%82" hreflang="wuu" lang="wuu" title="纽约市 – Wu Chinese">
#          吴语
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-yi">
#         <a class="interlanguage-link-target" href="https://yi.wikipedia.org/wiki/%D7%A0%D7%99%D7%95_%D7%99%D7%90%D7%A8%D7%A7_%D7%A1%D7%99%D7%98%D7%99" hreflang="yi" lang="yi" title="ניו יארק סיטי – Yiddish">
#          ייִדיש
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-yo">
#         <a class="interlanguage-link-target" href="https://yo.wikipedia.org/wiki/New_York" hreflang="yo" lang="yo" title="New York – Yoruba">
#          Yorùbá
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh-yue">
#         <a class="interlanguage-link-target" href="https://zh-yue.wikipedia.org/wiki/%E7%B4%90%E7%B4%84" hreflang="yue" lang="yue" title="紐約 – Cantonese">
#          粵語
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-diq">
#         <a class="interlanguage-link-target" href="https://diq.wikipedia.org/wiki/New_York_City" hreflang="diq" lang="diq" title="New York City – Zazaki">
#          Zazaki
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zea">
#         <a class="interlanguage-link-target" href="https://zea.wikipedia.org/wiki/New_York_City" hreflang="zea" lang="zea" title="New York City – Zeelandic">
#          Zeêuws
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-bat-smg">
#         <a class="interlanguage-link-target" href="https://bat-smg.wikipedia.org/wiki/Niojuorks" hreflang="sgs" lang="sgs" title="Niojuorks – Samogitian">
#          Žemaitėška
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh">
#         <a class="interlanguage-link-target" href="https://zh.wikipedia.org/wiki/%E7%BA%BD%E7%BA%A6" hreflang="zh" lang="zh" title="纽约 – Chinese">
#          中文
#         </a>
#        </li>
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="wb-langlinks-edit wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q60#sitelinks-wikipedia" title="Edit interlanguage links">
#          Edit links
#         </a>
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="footer" role="contentinfo">
#    <ul class="" id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 17 April 2020, at 03:19
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul class="" id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#       Statistics
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=New_York_City&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" src="/static/images/poweredby_mediawiki_88x31.png" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#    <div style="clear: both;">
#    </div>
#   </div>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"5.420","walltime":"6.332","ppvisitednodes":{"value":47702,"limit":1000000},"postexpandincludesize":{"value":1578454,"limit":2097152},"templateargumentsize":{"value":237738,"limit":2097152},"expansiondepth":{"value":24,"limit":40},"expensivefunctioncount":{"value":44,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":2151852,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00% 4923.327      1 -total"," 52.22% 2571.157      2 Template:Reflist"," 25.56% 1258.348    321 Template:Cite_web"," 11.03%  543.141      1 Template:Infobox_settlement"," 10.63%  523.152      1 Template:Navboxes","  9.90%  487.245     12 Template:Navbox","  9.47%  466.036    110 Template:Cite_news","  9.42%  463.599      1 Template:Infobox","  8.61%  424.081      3 Template:Navbox_with_columns","  7.54%  371.338     70 Template:Flagicon"]},"scribunto":{"limitreport-timeusage":{"value":"2.578","limit":"10.000"},"limitreport-memusage":{"value":17244038,"limit":52428800},"limitreport-profile":[["?","520","17.2"],["Scribunto_LuaSandboxCallback::gsub","340","11.3"],["Scribunto_LuaSandboxCallback::getExpandedArgument","260","8.6"],["dataWrapper \u003Cmw.lua:661\u003E","220","7.3"],["Scribunto_LuaSandboxCallback::match","200","6.6"],["recursiveClone \u003CmwInit.lua:41\u003E","200","6.6"],["Scribunto_LuaSandboxCallback::getAllExpandedArguments","120","4.0"],["Scribunto_LuaSandboxCallback::anchorEncode","120","4.0"],["Scribunto_LuaSandboxCallback::find","100","3.3"],["type","80","2.6"],["[others]","860","28.5"]]},"cachereport":{"origin":"mw1393","timestamp":"20200419111344","ttl":86400,"transientcontent":true}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"New York City","url":"https:\/\/en.wikipedia.org\/wiki\/New_York_City","sameAs":"http:\/\/www.wikidata.org\/entity\/Q60","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q60","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2001-03-27T02:20:50Z","dateModified":"2020-04-17T03:19:51Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/f\/f7\/Lower_Manhattan_skyline_-_June_2017.jpg","headline":"city in state of New York, largest city in the United States by population"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":168,"wgHostname":"mw1385"});});
#   </script>
#  </body>
# </html>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-6937eb831ef5> in <module>
#       4 print(soup.prettify())
#       5
# ----> 6 headers = [header.text for header in table.find_all('th')]
#       7
#       8 table_rows = table.find_all('tr')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
Demo_data=pd.read_csv('NYC_DEMO.csv')
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
Demo_data
# Out:
#                                                       City compared to State & U.S. \n
# 2010 Census[233][234]            NY City   NY State                             U.S.\n
# Total population                 8,175,133 19,378,102                    308,745,538\n
# Population change, 2000 to 2010  +2.1%     +2.1%                               +9.7%\n
# Population density (people/sqmi) 27,012.5  411.2                                87.4\n
# Median household income (2015)   $53,373   $59,269                           $53,889\n
# Bachelor's degree or higher      35.7%     34.2%                               29.8%\n
# Foreign born                     37.2%     22.5%                               13.2%\n
# White (non-Hispanic)             44.0%     65.7%                               72.4%\n
# Black                            25.5%     15.9%                               12.6%\n
# Hispanic (any race)              28.6%     17.6%                               16.3%\n
# Asian                            12.7%     7.3%                                 4.8%\n

# %%
Demo_data.columns
# Out:
# Index(['City compared to State & U.S. \n'], dtype='object')

# %%
Demo_data.rename(columns = {'2010[237]' : '2010',
                   '1990[239]':'1990',
                   '1970[239]':'1970', 
                   '1940[239]\n':'1940',
                    }, inplace=True)
Demo_data
# Out:
#                                                       City compared to State & U.S. \n
# 2010 Census[233][234]            NY City   NY State                             U.S.\n
# Total population                 8,175,133 19,378,102                    308,745,538\n
# Population change, 2000 to 2010  +2.1%     +2.1%                               +9.7%\n
# Population density (people/sqmi) 27,012.5  411.2                                87.4\n
# Median household income (2015)   $53,373   $59,269                           $53,889\n
# Bachelor's degree or higher      35.7%     34.2%                               29.8%\n
# Foreign born                     37.2%     22.5%                               13.2%\n
# White (non-Hispanic)             44.0%     65.7%                               72.4%\n
# Black                            25.5%     15.9%                               12.6%\n
# Hispanic (any race)              28.6%     17.6%                               16.3%\n
# Asian                            12.7%     7.3%                                 4.8%\n

# %%
Demo_data.columns
# Out:
# Index(['City compared to State & U.S. \n'], dtype='object')

# %%
Demo_data.columns = Demo_data.columns.str.replace(' ', '')

# %%
Demo_data= Demo_data.replace('\n',' ', regex=True)
Demo_data
# Out:
#                                                       CitycomparedtoState&U.S. \n
# 2010 Census[233][234]            NY City   NY State                         U.S.
# Total population                 8,175,133 19,378,102                308,745,538
# Population change, 2000 to 2010  +2.1%     +2.1%                           +9.7%
# Population density (people/sqmi) 27,012.5  411.2                            87.4
# Median household income (2015)   $53,373   $59,269                       $53,889
# Bachelor's degree or higher      35.7%     34.2%                           29.8%
# Foreign born                     37.2%     22.5%                           13.2%
# White (non-Hispanic)             44.0%     65.7%                           72.4%
# Black                            25.5%     15.9%                           12.6%
# Hispanic (any race)              28.6%     17.6%                           16.3%
# Asian                            12.7%     7.3%                             4.8%

# %%
Demo_data.to_csv('BON2_DEMOGRAPHICS.csv',index=False)
